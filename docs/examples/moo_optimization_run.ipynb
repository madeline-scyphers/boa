# %% [markdown]
# # Running a Multi Objective Optimization Directly in Python
#
# This notebook demonstrates how to:
#
# Write a basic Wrapper in Python and launch a multi objective optimization from Python.
# If you wanted to launch it from command line, you would do a similar thing of defining the Wrapper, and then put in your configuration file the information about where the wrapper is, and use [BOA's](../index.rst) CLI tools. See [Running an Experiment from Command Line (Python Wrapper)](example_py_run.rst) for more information.

# %%
import pathlib

import yaml
import shutil

import boa
from boa.scripts.moo import Wrapper

# %%
# Remove old runs to have a clean slate for this example
old_runs = pathlib.Path().resolve().glob("moo_run*")
for path in old_runs:
    shutil.rmtree(path, ignore_errors=True)

# %% [markdown]
# ## Loading the Config File

# %%
config_path = pathlib.Path().resolve().parent.parent / "boa/scripts/moo.yaml"

# %% [markdown]
# Here we can see what the configuration file looks like

# %%
with open(config_path, 'r') as f:
    file_contents = f.read()
    print (file_contents)
# Out:
# # MultiObjective Optimization config
# optimization_options:
#     objective_options:
#         objective_thresholds:
#             - branin >= -194.3809113151761
#             - currin >= -10.521741333278536
#             - hartmann6 <= 0.2154494439486514
#         objectives:
#             - name: branin
#               lower_is_better: False
#               noise_sd: 0
#             - name: currin
#               lower_is_better: False
#               noise_sd: 0
#             - name: hartmann6
#               lower_is_better: True
#               noise_sd: 0
#
#     experiment:
#         name: "moo"
#     trials: 100
#
# parameters:
#     x0:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x1:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x2:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x3:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x4:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x5:
#         type: range
#         bounds: [0, 1]
#         value_type: float

# %%
config = boa.load_jsonlike(config_path)

# %% [markdown]
# ## Define Our Wrapper

# %% [markdown]
# We define our wrapper in wrapper.py and use a synthetic function that stands in for any black box model call

# %%
with open(Wrapper.path(), 'r') as f:
    file_contents = f.read()
    print (file_contents)
# Out:
# from pathlib import Path
#
# import numpy as np
# import torch
#
# from boa.controller import Controller
# from boa.metrics.synthetic_funcs import get_synth_func
# from boa.utils import torch_device
# from boa.wrappers.base_wrapper import BaseWrapper
#
# tkwargs = {
#     "device": torch_device(),
# }
# Problem = get_synth_func("BraninCurrin")
#
# problem = Problem(negate=True).to(**tkwargs)
# hartmann6 = get_synth_func("hartmann6")
#
#
# class Wrapper(BaseWrapper):
#     def run_model(self, trial) -> None:
#         pass
#
#     def set_trial_status(self, trial) -> None:
#         trial.mark_completed()
#
#     def fetch_trial_data(self, trial, metric_properties, metric_name, *args, **kwargs):
#         evaluation = problem(torch.tensor([trial.arm.parameters["x0"], trial.arm.parameters["x1"]]))
#         a = float(evaluation[0])
#         b = float(evaluation[1])
#         c = hartmann6(
#             np.array(
#                 [
#                     trial.arm.parameters["x0"],
#                     trial.arm.parameters["x1"],
#                     trial.arm.parameters["x2"],
#                     trial.arm.parameters["x3"],
#                     trial.arm.parameters["x4"],
#                     trial.arm.parameters["x5"],
#                 ]
#             )
#         )
#         return {
#             "branin": a,
#             "currin": b,
#             "hartmann6": c,
#         }
#
#
# def main():
#     config_path = Path(__file__).resolve().parent / "moo.yaml"
#     wrapper = Wrapper(config_path=config_path)
#     controller = Controller(wrapper=wrapper)
#     controller.initialize_scheduler()
#     return controller.run()
#
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Initialize our Setup

# %%
controller = boa.Controller(config_path=config_path, wrapper=Wrapper)

controller.initialize_scheduler()
# Out:
# [INFO 07-09 16:56:56] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x0', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x1', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x2', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x3', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x4', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x5', parameter_type=FLOAT, range=[0.0, 1.0])], parameter_constraints=[]).
# [INFO 07-09 16:56:56] ax.modelbridge.dispatch_utils: Using Models.MOO since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 07-09 16:56:56] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=6 num_trials=None use_batch_trials=False
# [INFO 07-09 16:56:56] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=12
# [INFO 07-09 16:56:56] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=12
# [INFO 07-09 16:56:56] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+MOO', steps=[Sobol for 12 trials, MOO for subsequent trials]). Iterations after 12 will take longer to generate due to model-fitting.
# [INFO 07-09 16:56:56] Scheduler: `Scheduler` requires experiment to have immutable search space and optimization config. Setting property immutable_search_space_and_opt_config to `True` on experiment.
# (Scheduler(experiment=Experiment(moo), generation_strategy=GenerationStrategy(name='Sobol+MOO', steps=[Sobol for 12 trials, MOO for subsequent trials]), options=SchedulerOptions(max_pending_trials=10, trial_type=<TrialType.TRIAL: 0>, batch_size=None, total_trials=None, tolerated_trial_failure_rate=0.5, min_failed_trials_for_failure_rate_check=5, log_filepath=None, logging_level=20, ttl_seconds_for_trials=None, init_seconds_between_polls=1, min_seconds_before_poll=1.0, seconds_between_polls_backoff_factor=1.5, timeout_hours=None, run_trials_in_batches=False, debug_log_run_metadata=False, early_stopping_strategy=None, global_stopping_strategy=None, suppress_storage_errors_after_retries=False)),
#  <boa.scripts.moo.Wrapper at 0x15546aec0>)

# %% [markdown]
# ## Run our Experiment

# %% [markdown]
# The Controller will save our scheduler to JSON after it completes the run so we can reload it at a later time for analysis or to resume our experiment

# %%
scheduler = controller.run()
# Out:
# [INFO 2023-07-09 16:17:54,917 MainProcess] boa:
#
# ##############################################
#
#
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752
# Start Time: 20230709T161754
# Version: 0.8.3.dev1+g0636f51.d20230411
#
# ##############################################
#
# [INFO 07-09 16:17:54] Scheduler: Running trials [0]...
# [INFO 07-09 16:17:55] Scheduler: Running trials [1]...
# [INFO 07-09 16:17:55] Scheduler: Running trials [2]...
# [INFO 07-09 16:17:56] Scheduler: Running trials [3]...
# [INFO 07-09 16:17:58] Scheduler: Running trials [4]...
# [INFO 07-09 16:17:59] Scheduler: Running trials [5]...
# [INFO 07-09 16:17:59] Scheduler: Running trials [6]...
# [INFO 07-09 16:18:00] Scheduler: Running trials [7]...
# [INFO 07-09 16:18:01] Scheduler: Running trials [8]...
# [INFO 07-09 16:18:02] Scheduler: Running trials [9]...
# [INFO 07-09 16:18:03] Scheduler: Retrieved COMPLETED trials: 0 - 9.
# [INFO 07-09 16:18:03] Scheduler: Fetching data for trials: 0 - 9.
# [ERROR 2023-07-09 16:18:03,342 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:18:03,357 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:18:03,374 MainProcess] boa: Trials so far: 10
# Running trials:
# Will Produce next trials from generation step: Sobol
# Best trial so far: {}
# [INFO 07-09 16:18:03] Scheduler: Running trials [10]...
# [INFO 07-09 16:18:04] Scheduler: Running trials [11]...
# [INFO 07-09 16:18:07] Scheduler: Running trials [12]...
# [INFO 07-09 16:18:11] Scheduler: Running trials [13]...
# [INFO 07-09 16:18:15] Scheduler: Running trials [14]...
# [INFO 07-09 16:18:16] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:18:16] Scheduler: Retrieved COMPLETED trials: 10 - 14.
# [INFO 07-09 16:18:16] Scheduler: Fetching data for trials: 10 - 14.
# [ERROR 2023-07-09 16:18:16,510 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:18:16,528 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:18:16,542 MainProcess] boa: Trials so far: 15
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:18:19] Scheduler: Running trials [15]...
# [INFO 07-09 16:18:24] Scheduler: Running trials [16]...
# [INFO 07-09 16:18:28] Scheduler: Running trials [17]...
# [INFO 07-09 16:18:29] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:18:29] Scheduler: Retrieved COMPLETED trials: 15 - 17.
# [INFO 07-09 16:18:29] Scheduler: Fetching data for trials: 15 - 17.
# [ERROR 2023-07-09 16:18:29,714 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:18:29,737 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:18:29,754 MainProcess] boa: Trials so far: 18
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:18:33] Scheduler: Running trials [18]...
# [INFO 07-09 16:18:38] Scheduler: Running trials [19]...
# [INFO 07-09 16:18:42] Scheduler: Running trials [20]...
# [INFO 07-09 16:18:43] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:18:43] Scheduler: Retrieved COMPLETED trials: 18 - 20.
# [INFO 07-09 16:18:43] Scheduler: Fetching data for trials: 18 - 20.
# [ERROR 2023-07-09 16:18:43,259 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:18:43,285 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:18:43,302 MainProcess] boa: Trials so far: 21
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:18:46] Scheduler: Running trials [21]...
# [INFO 07-09 16:18:50] Scheduler: Running trials [22]...
# [INFO 07-09 16:18:55] Scheduler: Running trials [23]...
# [INFO 07-09 16:18:56] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:18:56] Scheduler: Retrieved COMPLETED trials: 21 - 23.
# [INFO 07-09 16:18:56] Scheduler: Fetching data for trials: 21 - 23.
# [ERROR 2023-07-09 16:18:56,591 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:18:56,623 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:18:56,640 MainProcess] boa: Trials so far: 24
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:19:00] Scheduler: Running trials [24]...
# [INFO 07-09 16:19:04] Scheduler: Running trials [25]...
# [INFO 07-09 16:19:09] Scheduler: Running trials [26]...
# [INFO 07-09 16:19:10] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:19:10] Scheduler: Retrieved COMPLETED trials: 24 - 26.
# [INFO 07-09 16:19:10] Scheduler: Fetching data for trials: 24 - 26.
# [ERROR 2023-07-09 16:19:10,678 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:19:10,715 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:19:10,845 MainProcess] boa: Trials so far: 27
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:19:15] Scheduler: Running trials [27]...
# [INFO 07-09 16:19:20] Scheduler: Running trials [28]...
# [INFO 07-09 16:19:25] Scheduler: Running trials [29]...
# [INFO 07-09 16:19:25] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:19:25] Scheduler: Retrieved COMPLETED trials: 27 - 29.
# [INFO 07-09 16:19:25] Scheduler: Fetching data for trials: 27 - 29.
# [ERROR 2023-07-09 16:19:25,986 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:19:26,029 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:19:26,047 MainProcess] boa: Trials so far: 30
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:19:32] Scheduler: Running trials [30]...
# [INFO 07-09 16:19:38] Scheduler: Running trials [31]...
# [INFO 07-09 16:19:43] Scheduler: Running trials [32]...
# [INFO 07-09 16:19:44] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:19:44] Scheduler: Retrieved COMPLETED trials: 30 - 32.
# [INFO 07-09 16:19:44] Scheduler: Fetching data for trials: 30 - 32.
# [ERROR 2023-07-09 16:19:44,791 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:19:44,839 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:19:44,857 MainProcess] boa: Trials so far: 33
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:19:51] Scheduler: Running trials [33]...
# [INFO 07-09 16:19:59] Scheduler: Running trials [34]...
# [INFO 07-09 16:20:11] Scheduler: Running trials [35]...
# [INFO 07-09 16:20:11] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:20:11] Scheduler: Retrieved COMPLETED trials: 33 - 35.
# [INFO 07-09 16:20:11] Scheduler: Fetching data for trials: 33 - 35.
# [ERROR 2023-07-09 16:20:11,405 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:20:11,463 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:20:11,483 MainProcess] boa: Trials so far: 36
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:20:18] Scheduler: Running trials [36]...
# [INFO 07-09 16:20:28] Scheduler: Running trials [37]...
# [INFO 07-09 16:20:40] Scheduler: Running trials [38]...
# [INFO 07-09 16:20:41] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:20:41] Scheduler: Retrieved COMPLETED trials: 36 - 38.
# [INFO 07-09 16:20:41] Scheduler: Fetching data for trials: 36 - 38.
# [ERROR 2023-07-09 16:20:41,755 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:20:41,812 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:20:41,832 MainProcess] boa: Trials so far: 39
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:20:49] Scheduler: Running trials [39]...
# [INFO 07-09 16:20:59] Scheduler: Running trials [40]...
# [INFO 07-09 16:21:16] Scheduler: Running trials [41]...
# [INFO 07-09 16:21:17] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:21:17] Scheduler: Retrieved COMPLETED trials: 39 - 41.
# [INFO 07-09 16:21:17] Scheduler: Fetching data for trials: 39 - 41.
# [ERROR 2023-07-09 16:21:17,204 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:21:17,266 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:21:17,286 MainProcess] boa: Trials so far: 42
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:21:26] Scheduler: Running trials [42]...
# [INFO 07-09 16:21:38] Scheduler: Running trials [43]...
# [INFO 07-09 16:21:50] Scheduler: Running trials [44]...
# [INFO 07-09 16:21:51] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:21:51] Scheduler: Retrieved COMPLETED trials: 42 - 44.
# [INFO 07-09 16:21:51] Scheduler: Fetching data for trials: 42 - 44.
# [ERROR 2023-07-09 16:21:51,913 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:21:51,980 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:21:52,003 MainProcess] boa: Trials so far: 45
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:22:02] Scheduler: Running trials [45]...
# [INFO 07-09 16:22:14] Scheduler: Running trials [46]...
# [INFO 07-09 16:22:32] Scheduler: Running trials [47]...
# [INFO 07-09 16:22:33] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:22:33] Scheduler: Retrieved COMPLETED trials: 45 - 47.
# [INFO 07-09 16:22:33] Scheduler: Fetching data for trials: 45 - 47.
# [ERROR 2023-07-09 16:22:33,242 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:22:33,315 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:22:33,335 MainProcess] boa: Trials so far: 48
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:22:42] Scheduler: Running trials [48]...
# [INFO 07-09 16:22:56] Scheduler: Running trials [49]...
# [INFO 07-09 16:23:10] Scheduler: Running trials [50]...
# [INFO 07-09 16:23:11] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:23:11] Scheduler: Retrieved COMPLETED trials: 48 - 50.
# [INFO 07-09 16:23:11] Scheduler: Fetching data for trials: 48 - 50.
# [ERROR 2023-07-09 16:23:11,734 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:23:11,817 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:23:11,838 MainProcess] boa: Trials so far: 51
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:23:27] Scheduler: Running trials [51]...
# [INFO 07-09 16:23:42] Scheduler: Running trials [52]...
# [INFO 07-09 16:24:00] Scheduler: Running trials [53]...
# [INFO 07-09 16:24:01] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:24:01] Scheduler: Retrieved COMPLETED trials: 51 - 53.
# [INFO 07-09 16:24:01] Scheduler: Fetching data for trials: 51 - 53.
# [ERROR 2023-07-09 16:24:01,377 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:24:01,460 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:24:01,480 MainProcess] boa: Trials so far: 54
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:24:20] Scheduler: Running trials [54]...
# [INFO 07-09 16:24:34] Scheduler: Running trials [55]...
# [INFO 07-09 16:24:47] Scheduler: Running trials [56]...
# [INFO 07-09 16:24:48] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:24:48] Scheduler: Retrieved COMPLETED trials: 54 - 56.
# [INFO 07-09 16:24:48] Scheduler: Fetching data for trials: 54 - 56.
# [ERROR 2023-07-09 16:24:48,333 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:24:48,425 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:24:48,447 MainProcess] boa: Trials so far: 57
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:25:00] Scheduler: Running trials [57]...
# [INFO 07-09 16:25:14] Scheduler: Running trials [58]...
# [INFO 07-09 16:25:33] Scheduler: Running trials [59]...
# [INFO 07-09 16:25:34] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:25:34] Scheduler: Retrieved COMPLETED trials: 57 - 59.
# [INFO 07-09 16:25:34] Scheduler: Fetching data for trials: 57 - 59.
# [ERROR 2023-07-09 16:25:34,468 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:25:34,561 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:25:34,583 MainProcess] boa: Trials so far: 60
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:25:46] Scheduler: Running trials [60]...
# [INFO 07-09 16:25:59] Scheduler: Running trials [61]...
# [INFO 07-09 16:26:14] Scheduler: Running trials [62]...
# [INFO 07-09 16:26:15] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:26:15] Scheduler: Retrieved COMPLETED trials: 60 - 62.
# [INFO 07-09 16:26:15] Scheduler: Fetching data for trials: 60 - 62.
# [ERROR 2023-07-09 16:26:15,655 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:26:15,755 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:26:15,778 MainProcess] boa: Trials so far: 63
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:26:27] Scheduler: Running trials [63]...
# [INFO 07-09 16:26:41] Scheduler: Running trials [64]...
# [INFO 07-09 16:26:58] Scheduler: Running trials [65]...
# [INFO 07-09 16:26:59] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:26:59] Scheduler: Retrieved COMPLETED trials: 63 - 65.
# [INFO 07-09 16:26:59] Scheduler: Fetching data for trials: 63 - 65.
# [ERROR 2023-07-09 16:26:59,619 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:26:59,726 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:26:59,749 MainProcess] boa: Trials so far: 66
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:27:13] Scheduler: Running trials [66]...
# [INFO 07-09 16:27:31] Scheduler: Running trials [67]...
# [INFO 07-09 16:27:48] Scheduler: Running trials [68]...
# [INFO 07-09 16:27:48] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:27:48] Scheduler: Retrieved COMPLETED trials: 66 - 68.
# [INFO 07-09 16:27:48] Scheduler: Fetching data for trials: 66 - 68.
# [ERROR 2023-07-09 16:27:48,376 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:27:48,488 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:27:48,511 MainProcess] boa: Trials so far: 69
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:28:00] Scheduler: Running trials [69]...
# [INFO 07-09 16:28:18] Scheduler: Running trials [70]...
# [INFO 07-09 16:28:29] Scheduler: Running trials [71]...
# [INFO 07-09 16:28:31] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:28:31] Scheduler: Retrieved COMPLETED trials: 69 - 71.
# [INFO 07-09 16:28:31] Scheduler: Fetching data for trials: 69 - 71.
# [ERROR 2023-07-09 16:28:31,202 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:28:31,309 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:28:31,332 MainProcess] boa: Trials so far: 72
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:28:45] Scheduler: Running trials [72]...
# [INFO 07-09 16:29:03] Scheduler: Running trials [73]...
# [INFO 07-09 16:29:19] Scheduler: Running trials [74]...
# [INFO 07-09 16:29:20] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:29:20] Scheduler: Retrieved COMPLETED trials: 72 - 74.
# [INFO 07-09 16:29:20] Scheduler: Fetching data for trials: 72 - 74.
# [ERROR 2023-07-09 16:29:20,142 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:29:20,297 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:29:20,325 MainProcess] boa: Trials so far: 75
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:29:41] Scheduler: Running trials [75]...
# [INFO 07-09 16:30:08] Scheduler: Running trials [76]...
# [INFO 07-09 16:30:37] Scheduler: Running trials [77]...
# [INFO 07-09 16:30:39] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:30:39] Scheduler: Retrieved COMPLETED trials: 75 - 77.
# [INFO 07-09 16:30:39] Scheduler: Fetching data for trials: 75 - 77.
# [ERROR 2023-07-09 16:30:39,423 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:30:39,903 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:30:39,948 MainProcess] boa: Trials so far: 78
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:31:18] Scheduler: Running trials [78]...
# [INFO 07-09 16:31:40] Scheduler: Running trials [79]...
# [INFO 07-09 16:32:03] Scheduler: Running trials [80]...
# [INFO 07-09 16:32:05] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:32:05] Scheduler: Retrieved COMPLETED trials: 78 - 80.
# [INFO 07-09 16:32:05] Scheduler: Fetching data for trials: 78 - 80.
# [ERROR 2023-07-09 16:32:05,215 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:32:05,437 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:32:05,479 MainProcess] boa: Trials so far: 81
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:32:25] Scheduler: Running trials [81]...
# [INFO 07-09 16:32:41] Scheduler: Running trials [82]...
# [INFO 07-09 16:33:02] Scheduler: Running trials [83]...
# [INFO 07-09 16:33:02] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:33:02] Scheduler: Retrieved COMPLETED trials: 81 - 83.
# [INFO 07-09 16:33:02] Scheduler: Fetching data for trials: 81 - 83.
# [ERROR 2023-07-09 16:33:02,671 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:33:02,809 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:33:02,836 MainProcess] boa: Trials so far: 84
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:33:23] Scheduler: Running trials [84]...
# [INFO 07-09 16:33:44] Scheduler: Running trials [85]...
# [INFO 07-09 16:34:03] Scheduler: Running trials [86]...
# [INFO 07-09 16:34:04] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:34:04] Scheduler: Retrieved COMPLETED trials: 84 - 86.
# [INFO 07-09 16:34:04] Scheduler: Fetching data for trials: 84 - 86.
# [ERROR 2023-07-09 16:34:05,010 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:34:05,151 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:34:05,178 MainProcess] boa: Trials so far: 87
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:34:24] Scheduler: Running trials [87]...
# [INFO 07-09 16:34:45] Scheduler: Running trials [88]...
# [INFO 07-09 16:35:56] Scheduler: Running trials [89]...
# [INFO 07-09 16:35:58] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:35:58] Scheduler: Retrieved COMPLETED trials: 87 - 89.
# [INFO 07-09 16:35:58] Scheduler: Fetching data for trials: 87 - 89.
# [ERROR 2023-07-09 16:35:58,084 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:35:58,497 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:35:58,524 MainProcess] boa: Trials so far: 90
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:36:29] Scheduler: Running trials [90]...
# [INFO 07-09 16:36:52] Scheduler: Running trials [91]...
# [INFO 07-09 16:37:22] Scheduler: Running trials [92]...
# [INFO 07-09 16:37:23] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:37:23] Scheduler: Retrieved COMPLETED trials: 90 - 92.
# [INFO 07-09 16:37:23] Scheduler: Fetching data for trials: 90 - 92.
# [ERROR 2023-07-09 16:37:23,461 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:37:23,600 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:37:23,626 MainProcess] boa: Trials so far: 93
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:37:47] Scheduler: Running trials [93]...
# [INFO 07-09 16:38:15] Scheduler: Running trials [94]...
# [INFO 07-09 16:38:34] Scheduler: Running trials [95]...
# [INFO 07-09 16:38:35] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:38:35] Scheduler: Retrieved COMPLETED trials: 93 - 95.
# [INFO 07-09 16:38:35] Scheduler: Fetching data for trials: 93 - 95.
# [ERROR 2023-07-09 16:38:35,295 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:38:35,450 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:38:35,478 MainProcess] boa: Trials so far: 96
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:39:10] Scheduler: Running trials [96]...
# [INFO 07-09 16:39:35] Scheduler: Running trials [97]...
# [INFO 07-09 16:40:05] Scheduler: Running trials [98]...
# [INFO 07-09 16:40:07] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-09 16:40:07] Scheduler: Retrieved COMPLETED trials: 96 - 98.
# [INFO 07-09 16:40:07] Scheduler: Fetching data for trials: 96 - 98.
# [ERROR 2023-07-09 16:40:07,122 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:40:07,276 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:40:07,302 MainProcess] boa: Trials so far: 99
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 07-09 16:40:34] Scheduler: Running trials [99]...
# [INFO 07-09 16:40:35] Scheduler: Retrieved COMPLETED trials: [99].
# [INFO 07-09 16:40:35] Scheduler: Fetching data for trials: [99].
# [ERROR 2023-07-09 16:40:35,109 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:40:35,268 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:40:35,297 MainProcess] boa: Trials so far: 100
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [ERROR 2023-07-09 16:40:35,298 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x151c27eb0> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-09 16:40:35,452 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752/scheduler.json`.
# Boa version: 0.8.3.dev1+g0636f51.d20230411
# [INFO 2023-07-09 16:40:35,479 MainProcess] boa: Trials so far: 100
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {}
# [INFO 2023-07-09 16:40:35,516 MainProcess] boa:
#
# ##############################################
#
# Trials Completed!
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_20230709T161752
# Start Time: 20230709T161754
# Version: 0.8.3.dev1+g0636f51.d20230411
# End Time: 20230709T164035
# Total Run Time: 1360.5631639957428
#
#     trial_index arm_name trial_status generation_method      branin  \
# 0             0      0_0    COMPLETED             Sobol  -36.634632
# 1             1      1_0    COMPLETED             Sobol -112.778679
# 2             2      2_0    COMPLETED             Sobol   -4.082886
# 3             3      3_0    COMPLETED             Sobol  -26.213963
# 4             4      4_0    COMPLETED             Sobol -106.169212
# ..          ...      ...          ...               ...         ...
# 95           95     95_0    COMPLETED               MOO   -5.119286
# 96           96     96_0    COMPLETED               MOO  -89.567719
# 97           97     97_0    COMPLETED               MOO  -33.107964
# 98           98     98_0    COMPLETED               MOO  -28.493637
# 99           99     99_0    COMPLETED               MOO   -0.639721
#
#        currin  hartmann6  is_feasible        x0        x1        x2        x3  \
# 0   -9.819938  -0.148712         True  0.148094  0.363476  0.832613  0.256167
# 1   -5.320959  -0.054360         True  0.696158  0.732111  0.015850  0.195221
# 2  -11.484652  -0.777353        False  0.536404  0.029499  0.132064  0.263329
# 3   -8.252074  -0.034296         True  0.650621  0.354788  0.427290  0.467677
# 4   -5.194883  -0.068215         True  0.040029  0.369770  0.847179  0.403704
# ..        ...        ...          ...       ...       ...       ...       ...
# 95  -7.364519  -1.556391         True  0.154475  0.617918  0.489384  0.266104
# 96  -6.709397  -2.656048         True  0.062193  0.358119  0.489988  0.262868
# 97  -9.333147  -2.665807         True  0.142431  0.395321  0.493059  0.262026
# 98  -1.299150  -0.437964         True  0.000000  0.881082  0.530632  0.267201
# 99  -6.036124  -0.859846         True  0.130771  0.772778  0.493084  0.292726
#
#           x4        x5
# 0   0.894928  0.794160
# 1   0.615510  0.840452
# 2   0.070673  0.622516
# 3   0.811935  0.700294
# 4   0.845237  0.908341
# ..       ...       ...
# 95  0.315524  0.664733
# 96  0.317533  0.672615
# 97  0.313797  0.672195
# 98  0.332852  0.589326
# 99  0.315734  0.649954
#
# [100 rows x 14 columns]
#
# ##############################################

# %% [markdown]
# ## Get the Best Trial and Output All Trials

# %%
trial = scheduler.best_raw_trials()
trial

# %%
boa.scheduler_to_df(scheduler)
# Out:
#     trial_index arm_name trial_status generation_method      branin  \
# 0             0      0_0    COMPLETED             Sobol  -36.634632
# 1             1      1_0    COMPLETED             Sobol -112.778679
# 2             2      2_0    COMPLETED             Sobol   -4.082886
# 3             3      3_0    COMPLETED             Sobol  -26.213963
# 4             4      4_0    COMPLETED             Sobol -106.169212
# ..          ...      ...          ...               ...         ...
# 95           95     95_0    COMPLETED               MOO   -5.119286
# 96           96     96_0    COMPLETED               MOO  -89.567719
# 97           97     97_0    COMPLETED               MOO  -33.107964
# 98           98     98_0    COMPLETED               MOO  -28.493637
# 99           99     99_0    COMPLETED               MOO   -0.639721
#
#        currin  hartmann6  is_feasible        x0        x1        x2        x3  \
# 0   -9.819938  -0.148712         True  0.148094  0.363476  0.832613  0.256167
# 1   -5.320959  -0.054360         True  0.696158  0.732111  0.015850  0.195221
# 2  -11.484652  -0.777353        False  0.536404  0.029499  0.132064  0.263329
# 3   -8.252074  -0.034296         True  0.650621  0.354788  0.427290  0.467677
# 4   -5.194883  -0.068215         True  0.040029  0.369770  0.847179  0.403704
# ..        ...        ...          ...       ...       ...       ...       ...
# 95  -7.364519  -1.556391         True  0.154475  0.617918  0.489384  0.266104
# 96  -6.709397  -2.656048         True  0.062193  0.358119  0.489988  0.262868
# 97  -9.333147  -2.665807         True  0.142431  0.395321  0.493059  0.262026
# 98  -1.299150  -0.437964         True  0.000000  0.881082  0.530632  0.267201
# 99  -6.036124  -0.859846         True  0.130771  0.772778  0.493084  0.292726
#
#           x4        x5
# 0   0.894928  0.794160
# 1   0.615510  0.840452
# 2   0.070673  0.622516
# 3   0.811935  0.700294
# 4   0.845237  0.908341
# ..       ...       ...
# 95  0.315524  0.664733
# 96  0.317533  0.672615
# 97  0.313797  0.672195
# 98  0.332852  0.589326
# 99  0.315734  0.649954
#
# [100 rows x 14 columns]
