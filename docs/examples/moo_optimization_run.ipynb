# %% [markdown]
# # Running a Multi Objective Optimization Directly in Python
#
# This notebook demonstrates how to:
#
# Write a basic Wrapper in Python and launch a multi objective optimization from Python.
# If you wanted to launch it from command line, you would do a similar thing of defining the Wrapper, and then put in your configuration file the information about where the wrapper is, and use [BOA's](../index.rst) CLI tools. See [Running an Experiment from Command Line (Python Wrapper)](example_py_run.rst) for more information.

# %%
import pathlib
import shutil

from IPython.display import Code

import boa
from boa.scripts.moo import Wrapper
# Out:
# [WARNING 07-12 15:41:23] ax.service.utils.with_db_settings_base: Ax currently requires a sqlalchemy version below 2.0. This will be addressed in a future release. Disabling SQL storage in Ax for now, if you would like to use SQL storage please install Ax with mysql extras via `pip install ax-platform[mysql]`.
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='669abd1a-6bec-429d-8a0e-b23f3c4d1f80'>
#   <div id="b50228ee-a187-4243-b926-bc2e6247c64a" data-root-id="669abd1a-6bec-429d-8a0e-b23f3c4d1f80" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a18fd52b-a21c-4fe0-be83-d402d38853e9":{"version":"3.2.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"669abd1a-6bec-429d-8a0e-b23f3c4d1f80"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"30a2e4ba-368f-4679-b8a4-fe89f16b3d34","attributes":{"plot_id":"669abd1a-6bec-429d-8a0e-b23f3c4d1f80","comm_id":"92b3dc81259c4379be32250a34f81a7f","client_comm_id":"22b5388b790d416d89aa0d2df7da33fd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"a18fd52b-a21c-4fe0-be83-d402d38853e9","roots":{"669abd1a-6bec-429d-8a0e-b23f3c4d1f80":"b50228ee-a187-4243-b926-bc2e6247c64a"},"root_ids":["669abd1a-6bec-429d-8a0e-b23f3c4d1f80"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Remove old runs to have a clean slate for this example
old_runs = pathlib.Path().resolve().glob("moo_run*")
for path in old_runs:
    shutil.rmtree(path, ignore_errors=True)

# %% [markdown]
# ## Loading the MOO Config File

# %%
config_path = pathlib.Path().resolve().parent.parent / "boa/scripts/moo.yaml"

# %% [markdown]
# Here we can see what the configuration file looks like

# %%
Code(config_path)
# Out:
# # MultiObjective Optimization config
# optimization_options:
#     objective_options:
#         objective_thresholds:
#             - branin >= -18.0
#             - currin >= -6.0
#         objectives:
#             - name: branin
#               lower_is_better: False
#               noise_sd: 0
#             - name: currin
#               lower_is_better: False
#               noise_sd: 0
#
#     experiment:
#         name: "moo_run"
#     trials: 50
#
# parameters:
#     x0:
#         type: range
#         bounds: [0, 1]
#         value_type: float
#     x1:
#         type: range
#         bounds: [0, 1]
#         value_type: float

# %%
config = boa.load_jsonlike(config_path)

# %% [markdown]
# ## The Wrapper

# %% [markdown]
# We define our wrapper in wrapper.py and use a synthetic function that stands in for any black box model call

# %%
Code(Wrapper.path())
# Out:
# from pathlib import Path
#
# import torch
#
# from boa.controller import Controller
# from boa.metrics.synthetic_funcs import get_synth_func
# from boa.utils import torch_device
# from boa.wrappers.base_wrapper import BaseWrapper
#
# tkwargs = {
#     "device": torch_device(),
# }
# Problem = get_synth_func("BraninCurrin")
#
# problem = Problem(negate=True).to(**tkwargs)
#
#
# class Wrapper(BaseWrapper):
#     def run_model(self, trial) -> None:
#         pass
#
#     def set_trial_status(self, trial) -> None:
#         trial.mark_completed()
#
#     def fetch_trial_data(self, trial, metric_properties, metric_name, *args, **kwargs):
#         evaluation = problem(torch.tensor([trial.arm.parameters["x0"], trial.arm.parameters["x1"]]))
#         a = float(evaluation[0])
#         b = float(evaluation[1])
#         return {"branin": a, "currin": b}
#
#
# def main():
#     config_path = Path(__file__).resolve().parent / "moo.yaml"
#     wrapper = Wrapper(config_path=config_path)
#     controller = Controller(wrapper=wrapper)
#     controller.initialize_scheduler()
#     return controller.run()
#
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## The Setup

# %%
controller = boa.Controller(config_path=config_path, wrapper=Wrapper)

controller.initialize_scheduler()
# Out:
# [INFO 07-12 15:41:24] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x0', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x1', parameter_type=FLOAT, range=[0.0, 1.0])], parameter_constraints=[]).
# [INFO 07-12 15:41:24] ax.modelbridge.dispatch_utils: Using Models.MOO since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 07-12 15:41:24] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 07-12 15:41:24] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 07-12 15:41:24] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 07-12 15:41:24] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+MOO', steps=[Sobol for 5 trials, MOO for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 07-12 15:41:24] Scheduler: `Scheduler` requires experiment to have immutable search space and optimization config. Setting property immutable_search_space_and_opt_config to `True` on experiment.
# (Scheduler(experiment=Experiment(moo_run), generation_strategy=GenerationStrategy(name='Sobol+MOO', steps=[Sobol for 5 trials, MOO for subsequent trials]), options=SchedulerOptions(max_pending_trials=10, trial_type=<TrialType.TRIAL: 0>, batch_size=None, total_trials=None, tolerated_trial_failure_rate=0.5, min_failed_trials_for_failure_rate_check=5, log_filepath=None, logging_level=20, ttl_seconds_for_trials=None, init_seconds_between_polls=1, min_seconds_before_poll=1.0, seconds_between_polls_backoff_factor=1.5, timeout_hours=None, run_trials_in_batches=False, debug_log_run_metadata=False, early_stopping_strategy=None, global_stopping_strategy=None, suppress_storage_errors_after_retries=False)),
#  <boa.scripts.moo.Wrapper at 0x150c13a00>)

# %% [markdown]
# ## Start our Experiment

# %% [markdown]
# The Controller will save our scheduler to JSON after it completes the run so we can reload it at a later time for analysis or to resume our experiment

# %%
scheduler = controller.run()
# Out:
# [INFO 2023-07-12 15:41:24,856 MainProcess] boa:
#
# ##############################################
#
#
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124
# Start Time: 20230712T154124
# Version: 0.8.7.dev0+g78bf53c.d20230712
#
# ##############################################
#
# [INFO 07-12 15:41:24] Scheduler: Running trials [0]...
# [INFO 07-12 15:41:25] Scheduler: Running trials [1]...
# [INFO 07-12 15:41:26] Scheduler: Running trials [2]...
# [INFO 07-12 15:41:27] Scheduler: Running trials [3]...
# [INFO 07-12 15:41:28] Scheduler: Running trials [4]...
# [INFO 07-12 15:41:29] Scheduler: Generated all trials that can be generated currently. Model requires more data to generate more trials.
# [INFO 07-12 15:41:29] Scheduler: Retrieved COMPLETED trials: 0 - 4.
# [INFO 07-12 15:41:29] Scheduler: Fetching data for trials: 0 - 4.
# [ERROR 2023-07-12 15:41:29,995 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:30,004 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:30,062 MainProcess] boa: Trials so far: 5
# Running trials:
# Will Produce next trials from generation step: Sobol
# Best trial so far: {}
# [INFO 07-12 15:41:30] Scheduler: Running trials [5]...
# [INFO 07-12 15:41:31] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:31] Scheduler: Running trials [6]...
# [INFO 07-12 15:41:31] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:32] Scheduler: Running trials [7]...
# [INFO 07-12 15:41:33] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:33] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:41:33] Scheduler: Retrieved COMPLETED trials: 5 - 7.
# [INFO 07-12 15:41:33] Scheduler: Fetching data for trials: 5 - 7.
# [ERROR 2023-07-12 15:41:33,440 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:33,450 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:33,490 MainProcess] boa: Trials so far: 8
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045}}
# [INFO 07-12 15:41:33] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:34] Scheduler: Running trials [8]...
# [INFO 07-12 15:41:35] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:35] Scheduler: Running trials [9]...
# [INFO 07-12 15:41:36] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:36] Scheduler: Running trials [10]...
# [INFO 07-12 15:41:37] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:37] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:41:37] Scheduler: Retrieved COMPLETED trials: 8 - 10.
# [INFO 07-12 15:41:37] Scheduler: Fetching data for trials: 8 - 10.
# [ERROR 2023-07-12 15:41:37,943 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:37,964 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:38,015 MainProcess] boa: Trials so far: 11
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045}}
# [INFO 07-12 15:41:38] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:39] Scheduler: Running trials [11]...
# [INFO 07-12 15:41:40] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:40] Scheduler: Running trials [12]...
# [INFO 07-12 15:41:41] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:42] Scheduler: Running trials [13]...
# [INFO 07-12 15:41:43] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:43] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:41:43] Scheduler: Retrieved COMPLETED trials: 11 - 13.
# [INFO 07-12 15:41:43] Scheduler: Fetching data for trials: 11 - 13.
# [ERROR 2023-07-12 15:41:43,408 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:43,429 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:43,482 MainProcess] boa: Trials so far: 14
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  12: {'branin': -3.06099796295166, 'currin': -5.251454830169678}}
# [INFO 07-12 15:41:43] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:44] Scheduler: Running trials [14]...
# [INFO 07-12 15:41:45] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:45] Scheduler: Running trials [15]...
# [INFO 07-12 15:41:46] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:47] Scheduler: Running trials [16]...
# [INFO 07-12 15:41:48] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:48] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:41:48] Scheduler: Retrieved COMPLETED trials: 14 - 16.
# [INFO 07-12 15:41:48] Scheduler: Fetching data for trials: 14 - 16.
# [ERROR 2023-07-12 15:41:48,571 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:48,586 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:48,650 MainProcess] boa: Trials so far: 17
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  12: {'branin': -3.06099796295166, 'currin': -5.251454830169678},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752}}
# [INFO 07-12 15:41:48] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:49] Scheduler: Running trials [17]...
# [INFO 07-12 15:41:50] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:51] Scheduler: Running trials [18]...
# [INFO 07-12 15:41:52] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:53] Scheduler: Running trials [19]...
# [INFO 07-12 15:41:54] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:54] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:41:54] Scheduler: Retrieved COMPLETED trials: 17 - 19.
# [INFO 07-12 15:41:54] Scheduler: Fetching data for trials: 17 - 19.
# [ERROR 2023-07-12 15:41:54,376 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:41:54,404 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:41:54,547 MainProcess] boa: Trials so far: 20
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637}}
# [INFO 07-12 15:41:54] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:56] Scheduler: Running trials [20]...
# [INFO 07-12 15:41:57] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:58] Scheduler: Running trials [21]...
# [INFO 07-12 15:41:59] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:41:59] Scheduler: Running trials [22]...
# [INFO 07-12 15:42:00] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:00] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:00] Scheduler: Retrieved COMPLETED trials: 20 - 22.
# [INFO 07-12 15:42:00] Scheduler: Fetching data for trials: 20 - 22.
# [ERROR 2023-07-12 15:42:00,878 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:00,908 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:00,975 MainProcess] boa: Trials so far: 23
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727}}
# [INFO 07-12 15:42:00] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:01] Scheduler: Running trials [23]...
# [INFO 07-12 15:42:02] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:03] Scheduler: Running trials [24]...
# [INFO 07-12 15:42:04] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:04] Scheduler: Running trials [25]...
# [INFO 07-12 15:42:05] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:05] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:05] Scheduler: Retrieved COMPLETED trials: 23 - 25.
# [INFO 07-12 15:42:05] Scheduler: Fetching data for trials: 23 - 25.
# [ERROR 2023-07-12 15:42:05,874 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:05,901 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:05,964 MainProcess] boa: Trials so far: 26
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795}}
# [INFO 07-12 15:42:05] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:06] Scheduler: Running trials [26]...
# [INFO 07-12 15:42:07] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:08] Scheduler: Running trials [27]...
# [INFO 07-12 15:42:09] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:09] Scheduler: Running trials [28]...
# [INFO 07-12 15:42:10] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:10] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:10] Scheduler: Retrieved COMPLETED trials: 26 - 28.
# [INFO 07-12 15:42:10] Scheduler: Fetching data for trials: 26 - 28.
# [ERROR 2023-07-12 15:42:10,845 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:10,875 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:10,944 MainProcess] boa: Trials so far: 29
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807}}
# [INFO 07-12 15:42:10] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:11] Scheduler: Running trials [29]...
# [INFO 07-12 15:42:12] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:13] Scheduler: Running trials [30]...
# [INFO 07-12 15:42:14] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:15] Scheduler: Running trials [31]...
# [INFO 07-12 15:42:16] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:16] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:16] Scheduler: Retrieved COMPLETED trials: 29 - 31.
# [INFO 07-12 15:42:16] Scheduler: Fetching data for trials: 29 - 31.
# [ERROR 2023-07-12 15:42:16,216 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:16,250 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:16,316 MainProcess] boa: Trials so far: 32
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189}}
# [INFO 07-12 15:42:16] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:16] Scheduler: Running trials [32]...
# [INFO 07-12 15:42:17] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:18] Scheduler: Running trials [33]...
# [INFO 07-12 15:42:19] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:20] Scheduler: Running trials [34]...
# [INFO 07-12 15:42:21] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:21] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:21] Scheduler: Retrieved COMPLETED trials: 32 - 34.
# [INFO 07-12 15:42:21] Scheduler: Fetching data for trials: 32 - 34.
# [ERROR 2023-07-12 15:42:21,193 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:21,222 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:21,431 MainProcess] boa: Trials so far: 35
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074}}
# [INFO 07-12 15:42:21] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:22] Scheduler: Running trials [35]...
# [INFO 07-12 15:42:23] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:24] Scheduler: Running trials [36]...
# [INFO 07-12 15:42:25] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:27] Scheduler: Running trials [37]...
# [INFO 07-12 15:42:28] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:28] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:28] Scheduler: Retrieved COMPLETED trials: 35 - 37.
# [INFO 07-12 15:42:28] Scheduler: Fetching data for trials: 35 - 37.
# [ERROR 2023-07-12 15:42:28,315 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:28,388 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:28,639 MainProcess] boa: Trials so far: 38
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341}}
# [INFO 07-12 15:42:28] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:31] Scheduler: Running trials [38]...
# [INFO 07-12 15:42:32] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:33] Scheduler: Running trials [39]...
# [INFO 07-12 15:42:34] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:35] Scheduler: Running trials [40]...
# [INFO 07-12 15:42:36] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:36] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:36] Scheduler: Retrieved COMPLETED trials: 38 - 40.
# [INFO 07-12 15:42:36] Scheduler: Fetching data for trials: 38 - 40.
# [ERROR 2023-07-12 15:42:36,773 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:36,826 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:36,959 MainProcess] boa: Trials so far: 41
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#  38: {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#  39: {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#  40: {'branin': -5.893988132476807, 'currin': -3.0685372352600098}}
# [INFO 07-12 15:42:36] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:37] Scheduler: Running trials [41]...
# [INFO 07-12 15:42:38] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:40] Scheduler: Running trials [42]...
# [INFO 07-12 15:42:41] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:42] Scheduler: Running trials [43]...
# [INFO 07-12 15:42:43] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:43] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:43] Scheduler: Retrieved COMPLETED trials: 41 - 43.
# [INFO 07-12 15:42:43] Scheduler: Fetching data for trials: 41 - 43.
# [ERROR 2023-07-12 15:42:43,076 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:43,119 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:43,199 MainProcess] boa: Trials so far: 44
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  11: {'branin': -3.620069980621338, 'currin': -3.9369606971740723},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#  38: {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#  39: {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#  40: {'branin': -5.893988132476807, 'currin': -3.0685372352600098},
#  41: {'branin': -2.0204906463623047, 'currin': -4.388144493103027},
#  42: {'branin': -16.826242446899414, 'currin': -1.2666064500808716},
#  43: {'branin': -15.486967086791992, 'currin': -1.4415537118911743}}
# [INFO 07-12 15:42:43] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:43] Scheduler: Running trials [44]...
# [INFO 07-12 15:42:45] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:46] Scheduler: Running trials [45]...
# [INFO 07-12 15:42:47] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:47] Scheduler: Running trials [46]...
# [INFO 07-12 15:42:47] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:47] Scheduler: Generated all trials that can be generated currently. Max parallelism currently reached.
# [INFO 07-12 15:42:47] Scheduler: Retrieved COMPLETED trials: 44 - 46.
# [INFO 07-12 15:42:47] Scheduler: Fetching data for trials: 44 - 46.
# [ERROR 2023-07-12 15:42:47,822 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:47,875 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:47,957 MainProcess] boa: Trials so far: 47
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#  38: {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#  39: {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#  40: {'branin': -5.893988132476807, 'currin': -3.0685372352600098},
#  41: {'branin': -2.0204906463623047, 'currin': -4.388144493103027},
#  42: {'branin': -16.826242446899414, 'currin': -1.2666064500808716},
#  43: {'branin': -15.486967086791992, 'currin': -1.4415537118911743},
#  44: {'branin': -3.331249237060547, 'currin': -3.866548776626587},
#  45: {'branin': -10.667184829711914, 'currin': -2.1486093997955322},
#  46: {'branin': -2.6249327659606934, 'currin': -4.134521007537842}}
# [INFO 07-12 15:42:47] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:48] Scheduler: Running trials [47]...
# [INFO 07-12 15:42:49] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:50] Scheduler: Running trials [48]...
# [INFO 07-12 15:42:50] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 07-12 15:42:51] Scheduler: Running trials [49]...
# [INFO 07-12 15:42:52] Scheduler: Retrieved COMPLETED trials: 47 - 49.
# [INFO 07-12 15:42:52] Scheduler: Fetching data for trials: 47 - 49.
# [ERROR 2023-07-12 15:42:52,199 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:52,252 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 2023-07-12 15:42:52,362 MainProcess] boa: Trials so far: 50
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#  38: {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#  39: {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#  40: {'branin': -5.893988132476807, 'currin': -3.0685372352600098},
#  41: {'branin': -2.0204906463623047, 'currin': -4.388144493103027},
#  42: {'branin': -16.826242446899414, 'currin': -1.2666064500808716},
#  43: {'branin': -15.486967086791992, 'currin': -1.4415537118911743},
#  44: {'branin': -3.331249237060547, 'currin': -3.866548776626587},
#  45: {'branin': -10.667184829711914, 'currin': -2.1486093997955322},
#  46: {'branin': -2.6249327659606934, 'currin': -4.134521007537842},
#  47: {'branin': -4.642075061798096, 'currin': -3.4163553714752197},
#  48: {'branin': -14.182465553283691, 'currin': -1.6198813915252686},
#  49: {'branin': -0.5267772674560547, 'currin': -5.689561367034912}}
# [ERROR 2023-07-12 15:42:52,363 MainProcess] boa: Object <boa.scripts.moo.Wrapper object at 0x150c13a00> passed to `object_to_json` (of type <class 'boa.scripts.moo.Wrapper'>, module: boa.scripts.moo) is not registered with a corresponding encoder in ENCODER_REGISTRY.
# [INFO 2023-07-12 15:42:52,404 MainProcess] boa: Saved JSON-serialized state of optimization to `/Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124/scheduler.json`.
# Boa version: 0.8.7.dev0+g78bf53c.d20230712
# [INFO 07-12 15:42:52] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 2023-07-12 15:42:52,433 MainProcess] boa: Trials so far: 50
# Running trials:
# Will Produce next trials from generation step: MOO
# Best trial so far: {5: {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#  14: {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#  16: {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#  17: {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#  18: {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#  20: {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#  21: {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#  22: {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#  24: {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#  26: {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#  27: {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#  28: {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#  29: {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#  30: {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#  31: {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#  32: {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#  34: {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#  35: {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#  36: {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#  37: {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#  38: {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#  39: {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#  40: {'branin': -5.893988132476807, 'currin': -3.0685372352600098},
#  41: {'branin': -2.0204906463623047, 'currin': -4.388144493103027},
#  42: {'branin': -16.826242446899414, 'currin': -1.2666064500808716},
#  43: {'branin': -15.486967086791992, 'currin': -1.4415537118911743},
#  44: {'branin': -3.331249237060547, 'currin': -3.866548776626587},
#  45: {'branin': -10.667184829711914, 'currin': -2.1486093997955322},
#  46: {'branin': -2.6249327659606934, 'currin': -4.134521007537842},
#  47: {'branin': -4.642075061798096, 'currin': -3.4163553714752197},
#  48: {'branin': -14.182465553283691, 'currin': -1.6198813915252686},
#  49: {'branin': -0.5267772674560547, 'currin': -5.689561367034912}}
# [INFO 2023-07-12 15:42:52,450 MainProcess] boa:
#
# ##############################################
#
# Trials Completed!
# BOA Experiment Run
# Output Experiment Dir: /Users/madelinescyphers/Documents/projs_.nosync/boa/docs/examples/moo_run_20230712T154124
# Start Time: 20230712T154124
# Version: 0.8.7.dev0+g78bf53c.d20230712
# End Time: 20230712T154252
# Total Run Time: 87.57821989059448
#
#     trial_index arm_name trial_status generation_method      branin  \
# 0             0      0_0    COMPLETED             Sobol -113.532249
# 1             1      1_0    COMPLETED             Sobol  -44.721550
# 2             2      2_0    COMPLETED             Sobol  -43.894382
# 3             3      3_0    COMPLETED             Sobol  -30.345284
# 4             4      4_0    COMPLETED             Sobol  -27.990721
# 5             5      5_0    COMPLETED               MOO  -17.508297
# 6             6      6_0    COMPLETED               MOO -146.187546
# 7             7      7_0    COMPLETED               MOO -212.585266
# 8             8      8_0    COMPLETED               MOO  -37.165882
# 9             9      9_0    COMPLETED               MOO  -59.081509
# 10           10     10_0    COMPLETED               MOO  -10.960894
# 11           11     11_0    COMPLETED               MOO   -3.620070
# 12           12     12_0    COMPLETED               MOO   -3.060998
# 13           13     13_0    COMPLETED               MOO  -17.160809
# 14           14     14_0    COMPLETED               MOO   -8.119276
# 15           15     15_0    COMPLETED               MOO   -5.314958
# 16           16     16_0    COMPLETED               MOO  -12.289436
# 17           17     17_0    COMPLETED               MOO   -2.338537
# 18           18     18_0    COMPLETED               MOO   -5.594287
# 19           19     19_0    COMPLETED               MOO -145.872208
# 20           20     20_0    COMPLETED               MOO   -1.617208
# 21           21     21_0    COMPLETED               MOO  -10.140726
# 22           22     22_0    COMPLETED               MOO  -14.829614
# 23           23     23_0    COMPLETED               MOO -308.129059
# 24           24     24_0    COMPLETED               MOO   -4.343532
# 25           25     25_0    COMPLETED               MOO -246.635345
# 26           26     26_0    COMPLETED               MOO   -0.835842
# 27           27     27_0    COMPLETED               MOO   -6.599877
# 28           28     28_0    COMPLETED               MOO  -13.543038
# 29           29     29_0    COMPLETED               MOO   -2.945738
# 30           30     30_0    COMPLETED               MOO   -1.721097
# 31           31     31_0    COMPLETED               MOO  -16.152164
# 32           32     32_0    COMPLETED               MOO   -3.728940
# 33           33     33_0    COMPLETED               MOO  -20.544992
# 34           34     34_0    COMPLETED               MOO   -9.112854
# 35           35     35_0    COMPLETED               MOO   -0.530976
# 36           36     36_0    COMPLETED               MOO   -4.943639
# 37           37     37_0    COMPLETED               MOO  -11.200890
# 38           38     38_0    COMPLETED               MOO   -7.345010
# 39           39     39_0    COMPLETED               MOO   -1.198068
# 40           40     40_0    COMPLETED               MOO   -5.893988
# 41           41     41_0    COMPLETED               MOO   -2.020491
# 42           42     42_0    COMPLETED               MOO  -16.826242
# 43           43     43_0    COMPLETED               MOO  -15.486967
# 44           44     44_0    COMPLETED               MOO   -3.331249
# 45           45     45_0    COMPLETED               MOO  -10.667185
# 46           46     46_0    COMPLETED               MOO   -2.624933
# 47           47     47_0    COMPLETED               MOO   -4.642075
# 48           48     48_0    COMPLETED               MOO  -14.182466
# 49           49     49_0    COMPLETED               MOO   -0.526777
#
#        currin  is_feasible        x0        x1
# 0   -5.322686        False  0.718387  0.724738
# 1   -6.568293        False  0.425310  0.652382
# 2  -13.163971        False  0.299421  0.119499
# 3   -7.461972        False  0.606397  0.449150
# 4   -7.579548        False  0.378880  0.548004
# 5   -1.180408         True  0.000000  1.000000
# 6   -4.654686        False  0.483198  1.000000
# 7   -4.180200        False  0.737164  1.000000
# 8   -1.374134        False  0.000000  0.816231
# 9   -1.543584        False  0.000000  0.691914
# 10 -10.179487        False  1.000000  0.000000
# 11  -3.936961         True  0.076948  1.000000
# 12  -5.251455         True  0.126561  0.920574
# 13  -6.744413        False  1.000000  0.460263
# 14  -2.595150         True  0.035637  1.000000
# 15  -4.643495         True  0.108364  1.000000
# 16  -1.894729         True  0.017588  1.000000
# 17  -4.261848         True  0.082949  0.948725
# 18  -3.240276         True  0.052064  0.975870
# 19  -4.005316        False  1.000000  1.000000
# 20  -4.700750         True  0.098169  0.929201
# 21  -2.235421         True  0.026213  1.000000
# 22  -1.530380         True  0.008568  1.000000
# 23  -3.000000        False  0.000000  0.000000
# 24  -3.514983         True  0.061787  0.992914
# 25  -2.942900        False  0.000000  0.126213
# 26  -5.062827         True  0.106412  0.883019
# 27  -2.905346         True  0.044139  1.000000
# 28  -1.710444         True  0.013007  1.000000
# 29  -4.011113         True  0.074687  0.956020
# 30  -4.532765         True  0.088767  0.914774
# 31  -1.353686         True  0.004236  1.000000
# 32  -3.724768         True  0.067315  0.978848
# 33  -9.398741        False  0.808517  0.217384
# 34  -2.412479         True  0.030802  1.000000
# 35  -5.412422         True  0.117809  0.853372
# 36  -3.322211         True  0.056349  1.000000
# 37  -2.062946         True  0.021817  1.000000
# 38  -2.747590         True  0.039764  1.000000
# 39  -4.804817         True  0.097846  0.900691
# 40  -3.068537         True  0.048795  1.000000
# 41  -4.388144         True  0.085478  0.931407
# 42  -1.266606         True  0.002107  1.000000
# 43  -1.441554         True  0.006388  1.000000
# 44  -3.866549         True  0.071102  0.969088
# 45  -2.148609         True  0.023992  1.000000
# 46  -4.134521         True  0.078388  0.950042
# 47  -3.416355         True  0.059247  0.999746
# 48  -1.619881         True  0.010770  1.000000
# 49  -5.689561         True  0.128015  0.830629
#
# ##############################################

# %% [markdown]
# ## Get the Best Trial

# %% [markdown]
# `best_fitted_trials` uses the data to do a fitting from all trials and with the noise levels you provided (or if no noise levels was provided, it assumed an unknown level of noise and inferred the noise level from the trial runs)

# %%
trial = scheduler.best_fitted_trials()
trial
# Out:
# [INFO 07-12 15:42:52] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# {5: {'params': {'x0': 0.0, 'x1': 1.0},
#   'means': {'branin': -17.505605997314618, 'currin': -1.1799849654136283},
#   'cov_matrix': {'branin': {'branin': 0.00016739603823403323, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 2.7652045405482605e-06}}},
#  14: {'params': {'x0': 0.035636856421788085, 'x1': 1.0},
#   'means': {'branin': -8.119344052515487, 'currin': -2.5951129719484216},
#   'cov_matrix': {'branin': {'branin': 8.855842746248704e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.1939233173119022e-06}}},
#  16: {'params': {'x0': 0.017588339750180672, 'x1': 1.0},
#   'means': {'branin': -12.288751193998255, 'currin': -1.894749802532552},
#   'cov_matrix': {'branin': {'branin': 7.464126940058943e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.010590377746881e-06}}},
#  17: {'params': {'x0': 0.08294936796424292, 'x1': 0.9487254073685889},
#   'means': {'branin': -2.33868108158976, 'currin': -4.262037601705608},
#   'cov_matrix': {'branin': {'branin': 0.00017520444066466268, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.580456819587984e-06}}},
#  18: {'params': {'x0': 0.05206372849007834, 'x1': 0.9758696098125307},
#   'means': {'branin': -5.596075625597919, 'currin': -3.2401669548220804},
#   'cov_matrix': {'branin': {'branin': 0.00024858636342493427, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 3.866523874159931e-06}}},
#  20: {'params': {'x0': 0.09816888638831198, 'x1': 0.9292010699696941},
#   'means': {'branin': -1.618653603716309, 'currin': -4.701305102659514},
#   'cov_matrix': {'branin': {'branin': 0.000242911797874671, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 3.894662358551216e-06}}},
#  21: {'params': {'x0': 0.026212736434616562, 'x1': 1.0},
#   'means': {'branin': -10.140698818660049, 'currin': -2.23533459311345},
#   'cov_matrix': {'branin': {'branin': 6.898685073519092e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.022209866480268e-06}}},
#  22: {'params': {'x0': 0.008568085485731238, 'x1': 1.0},
#   'means': {'branin': -14.830523052827212, 'currin': -1.5305982803436677},
#   'cov_matrix': {'branin': {'branin': 5.920966840131302e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 9.151351340004884e-07}}},
#  24: {'params': {'x0': 0.06178719196614803, 'x1': 0.9929139264835969},
#   'means': {'branin': -4.341840152438479, 'currin': -3.515003983110784},
#   'cov_matrix': {'branin': {'branin': 0.00011957631175234636, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.2084668936396776e-06}}},
#  26: {'params': {'x0': 0.10641166125798958, 'x1': 0.8830193155015728},
#   'means': {'branin': -0.8360207776568647, 'currin': -5.06285860047884},
#   'cov_matrix': {'branin': {'branin': 0.00022587101147709493, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 2.764376477022635e-06}}},
#  27: {'params': {'x0': 0.04413909391440788, 'x1': 1.0},
#   'means': {'branin': -6.599486361365932, 'currin': -2.905366713030432},
#   'cov_matrix': {'branin': {'branin': 9.22918493245759e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.2642760308346298e-06}}},
#  28: {'params': {'x0': 0.013006684905154962, 'x1': 1.0},
#   'means': {'branin': -13.542738593980687, 'currin': -1.7105854239844072},
#   'cov_matrix': {'branin': {'branin': 6.637346378258094e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.0142154429658764e-06}}},
#  29: {'params': {'x0': 0.07468708434239076, 'x1': 0.9560197593669482},
#   'means': {'branin': -2.946624662576008, 'currin': -4.0110905441486135},
#   'cov_matrix': {'branin': {'branin': 0.00013113581420923782, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.4173142783599156e-06}}},
#  30: {'params': {'x0': 0.08876713448811231, 'x1': 0.9147742251085361},
#   'means': {'branin': -1.7235398497698267, 'currin': -4.5323266083469465},
#   'cov_matrix': {'branin': {'branin': 0.00019604864642583505, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 2.570236987953773e-06}}},
#  31: {'params': {'x0': 0.0042364323062232135, 'x1': 1.0},
#   'means': {'branin': -16.15357168669928, 'currin': -1.3537845894605227},
#   'cov_matrix': {'branin': {'branin': 5.779964765183563e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 9.558649108583582e-07}}},
#  32: {'params': {'x0': 0.06731496684045106, 'x1': 0.9788477622762106},
#   'means': {'branin': -3.72744398459289, 'currin': -3.7248260278776097},
#   'cov_matrix': {'branin': {'branin': 0.00013831351500756441, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.3346028339625972e-06}}},
#  34: {'params': {'x0': 0.030802150155929853, 'x1': 1.0},
#   'means': {'branin': -9.113012638246772, 'currin': -2.412404529462689},
#   'cov_matrix': {'branin': {'branin': 8.412043262423776e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.116059725355062e-06}}},
#  35: {'params': {'x0': 0.11780926525760434, 'x1': 0.8533718738046046},
#   'means': {'branin': -0.5313840103058833, 'currin': -5.412198161429193},
#   'cov_matrix': {'branin': {'branin': 0.0002471492582293287, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 3.7234197898249782e-06}}},
#  36: {'params': {'x0': 0.05634900030628511, 'x1': 1.0},
#   'means': {'branin': -4.944021832856672, 'currin': -3.322206927675553},
#   'cov_matrix': {'branin': {'branin': 9.90296909932426e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.4226913386156154e-06}}},
#  37: {'params': {'x0': 0.02181731120899953, 'x1': 1.0},
#   'means': {'branin': -11.200477718981237, 'currin': -2.0628884069620943},
#   'cov_matrix': {'branin': {'branin': 6.74282869323509e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 9.868079994795288e-07}}},
#  38: {'params': {'x0': 0.039763891325706874, 'x1': 1.0},
#   'means': {'branin': -7.344853184341346, 'currin': -2.7475854074076507},
#   'cov_matrix': {'branin': {'branin': 8.664039305592973e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.2285928462249102e-06}}},
#  39: {'params': {'x0': 0.09784634925503498, 'x1': 0.9006911111699883},
#   'means': {'branin': -1.1964513161387078, 'currin': -4.804674119940288},
#   'cov_matrix': {'branin': {'branin': 0.00019474678373600706, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 2.113446967999805e-06}}},
#  40: {'params': {'x0': 0.04879505481526283, 'x1': 1.0},
#   'means': {'branin': -5.8935807910866345, 'currin': -3.0685656625691133},
#   'cov_matrix': {'branin': {'branin': 0.00010926917072018949, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.312362188329872e-06}}},
#  41: {'params': {'x0': 0.085477670850442, 'x1': 0.9314069362399333},
#   'means': {'branin': -2.0175393285657215, 'currin': -4.388126359672023},
#   'cov_matrix': {'branin': {'branin': 0.0001607660047061533, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.4598341484656004e-06}}},
#  42: {'params': {'x0': 0.002106726913547345, 'x1': 1.0},
#   'means': {'branin': -16.826500831223868, 'currin': -1.2665087170300593},
#   'cov_matrix': {'branin': {'branin': 7.336751549784027e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.4377281152450435e-06}}},
#  43: {'params': {'x0': 0.0063883100131651134, 'x1': 1.0},
#   'means': {'branin': -15.488402652221447, 'currin': -1.4417485329580262},
#   'cov_matrix': {'branin': {'branin': 5.8580145419186856e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 8.676727741294702e-07}}},
#  44: {'params': {'x0': 0.071102355509788, 'x1': 0.9690880542801084},
#   'means': {'branin': -3.330695304205232, 'currin': -3.866601362662659},
#   'cov_matrix': {'branin': {'branin': 0.0001264886998482201, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.3331888476993484e-06}}},
#  45: {'params': {'x0': 0.023992044099351007, 'x1': 1.0},
#   'means': {'branin': -10.666977226765631, 'currin': -2.1485313614872754},
#   'cov_matrix': {'branin': {'branin': 6.545656607679402e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 9.943354561948297e-07}}},
#  46: {'params': {'x0': 0.07838816517329486, 'x1': 0.9500422257334257},
#   'means': {'branin': -2.625291036337675, 'currin': -4.13454003954949},
#   'cov_matrix': {'branin': {'branin': 0.00010323096969211994, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.2786744604855782e-06}}},
#  47: {'params': {'x0': 0.0592471789885062, 'x1': 0.9997464251371483},
#   'means': {'branin': -4.642655716714319, 'currin': -3.4163314304691177},
#   'cov_matrix': {'branin': {'branin': 0.00011242517653537532, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 1.5176332828544438e-06}}},
#  48: {'params': {'x0': 0.010770447735436306, 'x1': 1.0},
#   'means': {'branin': -14.18270774168479, 'currin': -1.6200748430590104},
#   'cov_matrix': {'branin': {'branin': 6.107458968572315e-05, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 9.773722680862876e-07}}},
#  49: {'params': {'x0': 0.12801476520535596, 'x1': 0.8306289412949485},
#   'means': {'branin': -0.5266372923011353, 'currin': -5.689639438903926},
#   'cov_matrix': {'branin': {'branin': 0.000254364081515864, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 5.051744824508752e-06}}}}

# %% [markdown]
# if you need the exact points of the best trial, maybe because you need the trial number of the best trial to plot results, or for any other reason, `best_raw_trails` does not do any fitting

# %%
trial = scheduler.best_raw_trials()
trial
# Out:
# [INFO 07-12 15:42:52] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# {5: {'params': {'x0': 0.0, 'x1': 1.0},
#   'means': {'branin': -17.508296966552734, 'currin': -1.180408000946045},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  14: {'params': {'x0': 0.035636856421788085, 'x1': 1.0},
#   'means': {'branin': -8.11927604675293, 'currin': -2.5951504707336426},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  16: {'params': {'x0': 0.017588339750180672, 'x1': 1.0},
#   'means': {'branin': -12.289436340332031, 'currin': -1.8947288990020752},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  17: {'params': {'x0': 0.08294936796424292, 'x1': 0.9487254073685889},
#   'means': {'branin': -2.3385372161865234, 'currin': -4.261847972869873},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  18: {'params': {'x0': 0.05206372849007834, 'x1': 0.9758696098125307},
#   'means': {'branin': -5.594286918640137, 'currin': -3.2402758598327637},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  20: {'params': {'x0': 0.09816888638831198, 'x1': 0.9292010699696941},
#   'means': {'branin': -1.617208480834961, 'currin': -4.700750350952148},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  21: {'params': {'x0': 0.026212736434616562, 'x1': 1.0},
#   'means': {'branin': -10.140726089477539, 'currin': -2.2354214191436768},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  22: {'params': {'x0': 0.008568085485731238, 'x1': 1.0},
#   'means': {'branin': -14.82961368560791, 'currin': -1.530380368232727},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  24: {'params': {'x0': 0.06178719196614803, 'x1': 0.9929139264835969},
#   'means': {'branin': -4.343531608581543, 'currin': -3.5149829387664795},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  26: {'params': {'x0': 0.10641166125798958, 'x1': 0.8830193155015728},
#   'means': {'branin': -0.8358421325683594, 'currin': -5.062826633453369},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  27: {'params': {'x0': 0.04413909391440788, 'x1': 1.0},
#   'means': {'branin': -6.599876880645752, 'currin': -2.905345916748047},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  28: {'params': {'x0': 0.013006684905154962, 'x1': 1.0},
#   'means': {'branin': -13.543038368225098, 'currin': -1.7104437351226807},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  29: {'params': {'x0': 0.07468708434239076, 'x1': 0.9560197593669482},
#   'means': {'branin': -2.945737838745117, 'currin': -4.011112689971924},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  30: {'params': {'x0': 0.08876713448811231, 'x1': 0.9147742251085361},
#   'means': {'branin': -1.7210969924926758, 'currin': -4.5327653884887695},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  31: {'params': {'x0': 0.0042364323062232135, 'x1': 1.0},
#   'means': {'branin': -16.152164459228516, 'currin': -1.353685736656189},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  32: {'params': {'x0': 0.06731496684045106, 'x1': 0.9788477622762106},
#   'means': {'branin': -3.728940010070801, 'currin': -3.7247676849365234},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  34: {'params': {'x0': 0.030802150155929853, 'x1': 1.0},
#   'means': {'branin': -9.11285400390625, 'currin': -2.4124789237976074},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  35: {'params': {'x0': 0.11780926525760434, 'x1': 0.8533718738046046},
#   'means': {'branin': -0.5309762954711914, 'currin': -5.412422180175781},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  36: {'params': {'x0': 0.05634900030628511, 'x1': 1.0},
#   'means': {'branin': -4.943639278411865, 'currin': -3.3222110271453857},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  37: {'params': {'x0': 0.02181731120899953, 'x1': 1.0},
#   'means': {'branin': -11.200889587402344, 'currin': -2.062945604324341},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  38: {'params': {'x0': 0.039763891325706874, 'x1': 1.0},
#   'means': {'branin': -7.345010280609131, 'currin': -2.747589588165283},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  39: {'params': {'x0': 0.09784634925503498, 'x1': 0.9006911111699883},
#   'means': {'branin': -1.1980676651000977, 'currin': -4.804816722869873},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  40: {'params': {'x0': 0.04879505481526283, 'x1': 1.0},
#   'means': {'branin': -5.893988132476807, 'currin': -3.0685372352600098},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  41: {'params': {'x0': 0.085477670850442, 'x1': 0.9314069362399333},
#   'means': {'branin': -2.0204906463623047, 'currin': -4.388144493103027},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  42: {'params': {'x0': 0.002106726913547345, 'x1': 1.0},
#   'means': {'branin': -16.826242446899414, 'currin': -1.2666064500808716},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  43: {'params': {'x0': 0.0063883100131651134, 'x1': 1.0},
#   'means': {'branin': -15.486967086791992, 'currin': -1.4415537118911743},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  44: {'params': {'x0': 0.071102355509788, 'x1': 0.9690880542801084},
#   'means': {'branin': -3.331249237060547, 'currin': -3.866548776626587},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  45: {'params': {'x0': 0.023992044099351007, 'x1': 1.0},
#   'means': {'branin': -10.667184829711914, 'currin': -2.1486093997955322},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  46: {'params': {'x0': 0.07838816517329486, 'x1': 0.9500422257334257},
#   'means': {'branin': -2.6249327659606934, 'currin': -4.134521007537842},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  47: {'params': {'x0': 0.0592471789885062, 'x1': 0.9997464251371483},
#   'means': {'branin': -4.642075061798096, 'currin': -3.4163553714752197},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  48: {'params': {'x0': 0.010770447735436306, 'x1': 1.0},
#   'means': {'branin': -14.182465553283691, 'currin': -1.6198813915252686},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}},
#  49: {'params': {'x0': 0.12801476520535596, 'x1': 0.8306289412949485},
#   'means': {'branin': -0.5267772674560547, 'currin': -5.689561367034912},
#   'cov_matrix': {'branin': {'branin': 0.0, 'currin': 0.0},
#    'currin': {'branin': 0.0, 'currin': 0.0}}}}

# %% [markdown]
# ## Output All Trials

# %%
boa.scheduler_to_df(scheduler)
# Out:
#     trial_index arm_name trial_status generation_method      branin  \
# 0             0      0_0    COMPLETED             Sobol -113.532249
# 1             1      1_0    COMPLETED             Sobol  -44.721550
# 2             2      2_0    COMPLETED             Sobol  -43.894382
# 3             3      3_0    COMPLETED             Sobol  -30.345284
# 4             4      4_0    COMPLETED             Sobol  -27.990721
# 5             5      5_0    COMPLETED               MOO  -17.508297
# 6             6      6_0    COMPLETED               MOO -146.187546
# 7             7      7_0    COMPLETED               MOO -212.585266
# 8             8      8_0    COMPLETED               MOO  -37.165882
# 9             9      9_0    COMPLETED               MOO  -59.081509
# 10           10     10_0    COMPLETED               MOO  -10.960894
# 11           11     11_0    COMPLETED               MOO   -3.620070
# 12           12     12_0    COMPLETED               MOO   -3.060998
# 13           13     13_0    COMPLETED               MOO  -17.160809
# 14           14     14_0    COMPLETED               MOO   -8.119276
# 15           15     15_0    COMPLETED               MOO   -5.314958
# 16           16     16_0    COMPLETED               MOO  -12.289436
# 17           17     17_0    COMPLETED               MOO   -2.338537
# 18           18     18_0    COMPLETED               MOO   -5.594287
# 19           19     19_0    COMPLETED               MOO -145.872208
# 20           20     20_0    COMPLETED               MOO   -1.617208
# 21           21     21_0    COMPLETED               MOO  -10.140726
# 22           22     22_0    COMPLETED               MOO  -14.829614
# 23           23     23_0    COMPLETED               MOO -308.129059
# 24           24     24_0    COMPLETED               MOO   -4.343532
# 25           25     25_0    COMPLETED               MOO -246.635345
# 26           26     26_0    COMPLETED               MOO   -0.835842
# 27           27     27_0    COMPLETED               MOO   -6.599877
# 28           28     28_0    COMPLETED               MOO  -13.543038
# 29           29     29_0    COMPLETED               MOO   -2.945738
# 30           30     30_0    COMPLETED               MOO   -1.721097
# 31           31     31_0    COMPLETED               MOO  -16.152164
# 32           32     32_0    COMPLETED               MOO   -3.728940
# 33           33     33_0    COMPLETED               MOO  -20.544992
# 34           34     34_0    COMPLETED               MOO   -9.112854
# 35           35     35_0    COMPLETED               MOO   -0.530976
# 36           36     36_0    COMPLETED               MOO   -4.943639
# 37           37     37_0    COMPLETED               MOO  -11.200890
# 38           38     38_0    COMPLETED               MOO   -7.345010
# 39           39     39_0    COMPLETED               MOO   -1.198068
# 40           40     40_0    COMPLETED               MOO   -5.893988
# 41           41     41_0    COMPLETED               MOO   -2.020491
# 42           42     42_0    COMPLETED               MOO  -16.826242
# 43           43     43_0    COMPLETED               MOO  -15.486967
# 44           44     44_0    COMPLETED               MOO   -3.331249
# 45           45     45_0    COMPLETED               MOO  -10.667185
# 46           46     46_0    COMPLETED               MOO   -2.624933
# 47           47     47_0    COMPLETED               MOO   -4.642075
# 48           48     48_0    COMPLETED               MOO  -14.182466
# 49           49     49_0    COMPLETED               MOO   -0.526777
#
#        currin  is_feasible        x0        x1
# 0   -5.322686        False  0.718387  0.724738
# 1   -6.568293        False  0.425310  0.652382
# 2  -13.163971        False  0.299421  0.119499
# 3   -7.461972        False  0.606397  0.449150
# 4   -7.579548        False  0.378880  0.548004
# 5   -1.180408         True  0.000000  1.000000
# 6   -4.654686        False  0.483198  1.000000
# 7   -4.180200        False  0.737164  1.000000
# 8   -1.374134        False  0.000000  0.816231
# 9   -1.543584        False  0.000000  0.691914
# 10 -10.179487        False  1.000000  0.000000
# 11  -3.936961         True  0.076948  1.000000
# 12  -5.251455         True  0.126561  0.920574
# 13  -6.744413        False  1.000000  0.460263
# 14  -2.595150         True  0.035637  1.000000
# 15  -4.643495         True  0.108364  1.000000
# 16  -1.894729         True  0.017588  1.000000
# 17  -4.261848         True  0.082949  0.948725
# 18  -3.240276         True  0.052064  0.975870
# 19  -4.005316        False  1.000000  1.000000
# 20  -4.700750         True  0.098169  0.929201
# 21  -2.235421         True  0.026213  1.000000
# 22  -1.530380         True  0.008568  1.000000
# 23  -3.000000        False  0.000000  0.000000
# 24  -3.514983         True  0.061787  0.992914
# 25  -2.942900        False  0.000000  0.126213
# 26  -5.062827         True  0.106412  0.883019
# 27  -2.905346         True  0.044139  1.000000
# 28  -1.710444         True  0.013007  1.000000
# 29  -4.011113         True  0.074687  0.956020
# 30  -4.532765         True  0.088767  0.914774
# 31  -1.353686         True  0.004236  1.000000
# 32  -3.724768         True  0.067315  0.978848
# 33  -9.398741        False  0.808517  0.217384
# 34  -2.412479         True  0.030802  1.000000
# 35  -5.412422         True  0.117809  0.853372
# 36  -3.322211         True  0.056349  1.000000
# 37  -2.062946         True  0.021817  1.000000
# 38  -2.747590         True  0.039764  1.000000
# 39  -4.804817         True  0.097846  0.900691
# 40  -3.068537         True  0.048795  1.000000
# 41  -4.388144         True  0.085478  0.931407
# 42  -1.266606         True  0.002107  1.000000
# 43  -1.441554         True  0.006388  1.000000
# 44  -3.866549         True  0.071102  0.969088
# 45  -2.148609         True  0.023992  1.000000
# 46  -4.134521         True  0.078388  0.950042
# 47  -3.416355         True  0.059247  0.999746
# 48  -1.619881         True  0.010770  1.000000
# 49  -5.689561         True  0.128015  0.830629
